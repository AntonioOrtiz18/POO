# %%
import numpy as np
import pandas as pd

# %%
Lista_1= np.linspace(-1,1,20)

# %%
Lista_1
# Out:
# array([-1.        , -0.89473684, -0.78947368, -0.68421053, -0.57894737,
#        -0.47368421, -0.36842105, -0.26315789, -0.15789474, -0.05263158,
#         0.05263158,  0.15789474,  0.26315789,  0.36842105,  0.47368421,
#         0.57894737,  0.68421053,  0.78947368,  0.89473684,  1.        ])

# %%
import random

# %%
Lista_2= np.random.randint(1500,3000,20)

# %%
Lista_2
# Out:
# array([2759, 2336, 2204, 1532, 1563, 2236, 1801, 2388, 2882, 1542, 2102,
#        1997, 2008, 2267, 2221, 2157, 2670, 2515, 2192, 1834])

# %%
diccionario = {"CapSmall" : Lista_1 ,"CapLarge" : Lista_2}

# %%
df=pd.DataFrame(diccionario)

# %%
df
# Out:
#     CapSmall  CapLarge
# 0  -1.000000      2759
# 1  -0.894737      2336
# 2  -0.789474      2204
# 3  -0.684211      1532
# 4  -0.578947      1563
# 5  -0.473684      2236
# 6  -0.368421      1801
# 7  -0.263158      2388
# 8  -0.157895      2882
# 9  -0.052632      1542
# 10  0.052632      2102
# 11  0.157895      1997
# 12  0.263158      2008
# 13  0.368421      2267
# 14  0.473684      2221
# 15  0.578947      2157
# 16  0.684211      2670
# 17  0.789474      2515
# 18  0.894737      2192
# 19  1.000000      1834

# %%
df=pd.DataFrame(diccionario,
                index= ["Año 1", "Año 2", "Año 3", "Año 4", "Año 5", "Año 6", "Año 7", "Año 8", "Año 9", "Año 10", "Año 11", "Año 12", "Año 13", "Año 14", "Año 15", "Año 16", "Año 17", "Año 18", "Año 19", "Año 20"])

# %%
df
# Out:
#         CapSmall  CapLarge
# Año 1  -1.000000      2759
# Año 2  -0.894737      2336
# Año 3  -0.789474      2204
# Año 4  -0.684211      1532
# Año 5  -0.578947      1563
# Año 6  -0.473684      2236
# Año 7  -0.368421      1801
# Año 8  -0.263158      2388
# Año 9  -0.157895      2882
# Año 10 -0.052632      1542
# Año 11  0.052632      2102
# Año 12  0.157895      1997
# Año 13  0.263158      2008
# Año 14  0.368421      2267
# Año 15  0.473684      2221
# Año 16  0.578947      2157
# Año 17  0.684211      2670
# Año 18  0.789474      2515
# Año 19  0.894737      2192
# Año 20  1.000000      1834

# %%
df.describe()
# Out:
#            CapSmall     CapLarge
# count  2.000000e+01    20.000000
# mean  -5.551115e-17  2160.300000
# std    6.227452e-01   383.474023
# min   -1.000000e+00  1532.000000
# 25%   -5.000000e-01  1956.250000
# 50%   -5.551115e-17  2198.000000
# 75%    5.000000e-01  2349.000000
# max    1.000000e+00  2882.000000

# %% [markdown]
# El valor mínimo de CapSmall es -1. El promedio es de -5.5511e-17, con una desviación estándar de 6.227452e-1. El primer quartil es -5.0e-1, la mediana -5.5511e-17 y el tercero 5.0e-1. El valor máximo es 1. Para Cap Large, el promedio es de 2160.3, con una desviación estandar de 383.474023, el primer cuatil en 1956.25, la media en 2198 y el tercer cuartil en 2349. El valor máximo de CapLarge est 2882.

# %%
d1=df.drop(columns="CapSmall")
d1.iloc[9:20]
# Out:
#         CapLarge
# Año 10      1542
# Año 11      2102
# Año 12      1997
# Año 13      2008
# Año 14      2267
# Año 15      2221
# Año 16      2157
# Año 17      2670
# Año 18      2515
# Año 19      2192
# Año 20      1834

# %%
d1.describe()
# Out:
#           CapLarge
# count    20.000000
# mean   2160.300000
# std     383.474023
# min    1532.000000
# 25%    1956.250000
# 50%    2198.000000
# 75%    2349.000000
# max    2882.000000

# %% [markdown]
# Promedio CapLarge años 10-20= 2160.3

# %%
import matplotlib.pyplot as plt
from pylab import plot

import seaborn as sns

# %%
d1.plot(label = "Cap Large", figsize = (15,8))
# Out:
# <Axes: >

# %%
m=d1[d1["CapLarge"]>2000]

# %%
m
# Out:
#         CapLarge
# Año 1       2759
# Año 2       2336
# Año 3       2204
# Año 6       2236
# Año 8       2388
# Año 9       2882
# Año 11      2102
# Año 13      2008
# Año 14      2267
# Año 15      2221
# Año 16      2157
# Año 17      2670
# Año 18      2515
# Año 19      2192

# %%
m.shape
# Out:
# (14, 1)
